# %% [markdown]
# ## Vishal's Homework

# %% [raw]
# Q1. Install MLflow
# To get started with MLflow you'll need to install the MLflow Python package.
#
# For this we recommend creating a separate Python environment, for example, you can use conda environments, and then install the package there with pip or conda.
#
# Once you installed the package, run the command mlflow --version and check the output.
#
# What's the version that you have?

# %%
# !mlflow --version
# Out:
# mlflow, version 2.16.2

# %% [markdown]
# ## ## Vishal's Answer for Q1 : mlflow, version 2.16.2

# %% [raw]
# Q2. Download and preprocess the data
# We'll use the Green Taxi Trip Records dataset to predict the duration of each trip.
#
# Download the data for January, February and March 2023 in parquet format from here.
#
# Use the script preprocess_data.py located in the folder homework to preprocess the data.
#
# The script will:
#
# load the data from the folder <TAXI_DATA_FOLDER> (the folder where you have downloaded the data),
# fit a DictVectorizer on the training set (January 2023 data),
# save the preprocessed datasets and the DictVectorizer to disk.
# Your task is to download the datasets and then execute this command:
#
# python preprocess_data.py --raw_data_path <TAXI_DATA_FOLDER> --dest_path ./output
# Tip: go to 02-experiment-tracking/homework/ folder before executing the command and change the value of <TAXI_DATA_FOLDER> to the location where you saved the data.
#
# How many files were saved to OUTPUT_FOLDER?
#
# 1
# 3
# 4
# 7
#
# Vishal's Answer : 4

# %%
# downloading the data from --> https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
# !python ./preprocess_data.py --raw_data_path /workspaces/mlops_zoomcamp_epam_vishal_sahare/02-Experiment-tracking/TAXI_DATA_FOLDER --dest_path ./output

# %%
# !pwd
# Out:
# /workspaces/mlops_zoomcamp_epam_vishal_sahare/02-Experiment-tracking

# %%
# !ls -lrt /workspaces/mlops_zoomcamp_epam_vishal_sahare/02-Experiment-tracking/output
# Out:
# total 7016
# -rw-rw-rw- 1 codespace codespace  131004 Oct  7 15:07 dv.pkl
# -rw-rw-rw- 1 codespace codespace 2374518 Oct  7 15:07 train.pkl
# -rw-rw-rw- 1 codespace codespace 2215824 Oct  7 15:07 val.pkl
# -rw-rw-rw- 1 codespace codespace 2458698 Oct  7 15:07 test.pkl

# %% [markdown]
# ## Vishal's Answer for Q2 : 4

# %% [raw]
# Q3. Train a model with autolog
# We will train a RandomForestRegressor (from Scikit-Learn) on the taxi dataset.
#
# We have prepared the training script train.py for this exercise, which can be also found in the folder homework.
#
# The script will:
#
# load the datasets produced by the previous step,
# train the model on the training set,
# calculate the RMSE score on the validation set.
# Your task is to modify the script to enable autologging with MLflow, execute the script and then launch the MLflow UI to check that the experiment run was properly tracked.
#
# Tip 1: don't forget to wrap the training code with a with mlflow.start_run(): statement as we showed in the videos.
#
# Tip 2: don't modify the hyperparameters of the model to make sure that the training will finish quickly.
#
# What is the value of the min_samples_split parameter:
#
# 2
# 4
# 8
# 10

# %%
# !pwd
# Out:
# /workspaces/mlops_zoomcamp_epam_vishal_sahare/02-Experiment-tracking

# %%
# !ls -lrt
# Out:
# total 260
# -rw-rw-rw-  1 codespace codespace     59 Oct  7 14:31 requirements.txt
# -rw-r--r--  1 codespace codespace 225280 Oct  7 14:36 mlflow.db
# drwxrwxrwx+ 2 codespace codespace   4096 Oct  7 15:00 TAXI_DATA_FOLDER
# -rw-rw-rw-  1 codespace codespace    972 Oct  7 15:05 train.py
# -rw-rw-rw-  1 codespace codespace   2728 Oct  7 15:05 register_model.py
# -rw-rw-rw-  1 codespace codespace   2510 Oct  7 15:05 preprocess_data.py
# -rw-rw-rw-  1 codespace codespace   1972 Oct  7 15:05 hpo.py
# drwxrwxrwx+ 2 codespace codespace   4096 Oct  7 15:07 output
# -rw-rw-rw-  1 codespace codespace   5763 Oct  7 15:13 02_homework_Experiment_tracking.ipynb

# %%
# !python train.py
# Out:
# 2024/10/07 15:16:53 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.5.1, but the installed version is 1.5.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2024/10/07 15:16:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# /home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## Vishal's Answer for Q3 :  min_samples_split = 2
#
# ![image.png](attachment:a077d9b9-698f-4961-b5fd-57c0f40c5894.png)

# %% [raw]
# Q4. Launch the tracking server locally
# Now we want to manage the entire lifecycle of our ML model. In this step, you'll need to launch a tracking server. This way we will also have access to the model registry.
#
# Your task is to:
#
# launch the tracking server on your local machine,
# select a SQLite db for the backend store and a folder called artifacts for the artifacts store.
# You should keep the tracking server running to work on the next two exercises that use the server.
#
# In addition to backend-store-uri, what else do you need to pass to properly configure the server?
#
# default-artifact-root
# serve-artifacts
# artifacts-only
# artifacts-destination

# %% [markdown]
# ## Vishal's Answer for Q4 : default-artifact-root
#
# ![image.png](attachment:a44c353f-60c9-4a3c-82d5-d8c308f02c2a.png)

# %% [raw]
# Q5. Tune model hyperparameters
# Now let's try to reduce the validation error by tuning the hyperparameters of the RandomForestRegressor using hyperopt. We have prepared the script hpo.py for this exercise.
#
# Your task is to modify the script hpo.py and make sure that the validation RMSE is logged to the tracking server for each run of the hyperparameter optimization (you will need to add a few lines of code to the objective function) and run the script without passing any parameters.
#
# After that, open UI and explore the runs from the experiment called random-forest-hyperopt to answer the question below.
#
# Note: Don't use autologging for this exercise.
#
# The idea is to just log the information that you need to answer the question below, including:
#
# the list of hyperparameters that are passed to the objective function during the optimization,
# the RMSE obtained on the validation set (February 2023 data).
# What's the best validation RMSE that you got?
#
# 4.817
# 5.335
# 5.818
# 6.336

# %%
# !pwd
# Out:
# /workspaces/mlops_zoomcamp_epam_vishal_sahare/02-Experiment-tracking

# %%
# !ls -lrt
# Out:
# total 364
# -rw-rw-rw-  1 codespace codespace     59 Oct  7 14:31 requirements.txt
# drwxrwxrwx+ 2 codespace codespace   4096 Oct  7 15:00 TAXI_DATA_FOLDER
# -rw-rw-rw-  1 codespace codespace    972 Oct  7 15:05 train.py
# -rw-rw-rw-  1 codespace codespace   2728 Oct  7 15:05 register_model.py
# -rw-rw-rw-  1 codespace codespace   2510 Oct  7 15:05 preprocess_data.py
# -rw-rw-rw-  1 codespace codespace   1972 Oct  7 15:05 hpo.py
# drwxrwxrwx+ 2 codespace codespace   4096 Oct  7 15:07 output
# drwxrwxrwx+ 3 codespace codespace   4096 Oct  7 15:15 mlruns
# -rw-r--r--  1 codespace codespace 225280 Oct  7 15:17 mlflow.db
# drwxrwxrwx+ 3 codespace codespace   4096 Oct  7 15:31 artifacts
# -rw-rw-rw-  1 codespace codespace 105312 Oct  7 15:33 02_homework_Experiment_tracking.ipynb

# %%
# !python hpo.py
# Out:
# 2024/10/07 15:35:25 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
#   0%|                                    | 0/15 [00:00<?, ?trial/s, best loss=?]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run nervous-ape-162 at: http://127.0.0.1:5000/#/experiments/2/runs/0e6417a64dab466f8417e4566c7b869c.
#
# 2024/10/07 15:35:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#   7%|▋          | 1/15 [00:07<01:49,  7.85s/trial, best loss: 5.370086069268862]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run skillful-pug-396 at: http://127.0.0.1:5000/#/experiments/2/runs/dd23dd782436490cbcc3f1ee9e94741b.
#
# 2024/10/07 15:35:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  13%|█▍         | 2/15 [00:08<00:46,  3.61s/trial, best loss: 5.370086069268862]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run gaudy-koi-209 at: http://127.0.0.1:5000/#/experiments/2/runs/65b9efc009044d4295493d01acfc36f3.
#
# 2024/10/07 15:35:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  20%|██▏        | 3/15 [00:09<00:28,  2.41s/trial, best loss: 5.370086069268862]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run gifted-robin-694 at: http://127.0.0.1:5000/#/experiments/2/runs/c8e9892398384efdb2bb6fbd715a3603.
#
# 2024/10/07 15:35:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  27%|██▉        | 4/15 [00:14<00:39,  3.63s/trial, best loss: 5.357490752366866]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run shivering-mouse-227 at: http://127.0.0.1:5000/#/experiments/2/runs/9493e1d5cdf149fab832c94cb5c33243.
#
# 2024/10/07 15:35:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  33%|███▋       | 5/15 [00:17<00:32,  3.27s/trial, best loss: 5.357490752366866]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:35:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run nervous-hare-986 at: http://127.0.0.1:5000/#/experiments/2/runs/e1f38a395b71459e847445855c5043e1.
#
# 2024/10/07 15:35:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  40%|████▍      | 6/15 [00:26<00:47,  5.23s/trial, best loss: 5.354695072530291]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run able-pig-951 at: http://127.0.0.1:5000/#/experiments/2/runs/553069c8a71b411eb713221298d656d2.
#
# 2024/10/07 15:36:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  47%|█████▏     | 7/15 [00:35<00:51,  6.38s/trial, best loss: 5.354695072530291]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run efficient-dog-637 at: http://127.0.0.1:5000/#/experiments/2/runs/27e3827c8fc949aabb57d9f9eefd3bff.
#
# 2024/10/07 15:36:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  53%|█████▊     | 8/15 [00:36<00:32,  4.69s/trial, best loss: 5.354695072530291]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run casual-turtle-233 at: http://127.0.0.1:5000/#/experiments/2/runs/62ee5263035c4b9cb0e8e525e4dcf6be.
#
# 2024/10/07 15:36:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  60%|██████▌    | 9/15 [00:41<00:29,  4.94s/trial, best loss: 5.354695072530291]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run bustling-lynx-698 at: http://127.0.0.1:5000/#/experiments/2/runs/ef15c8d20bfb468890f3fe4aa330fb10.
#
# 2024/10/07 15:36:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  67%|██████▋   | 10/15 [00:46<00:24,  4.81s/trial, best loss: 5.354695072530291]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run angry-goose-556 at: http://127.0.0.1:5000/#/experiments/2/runs/56223859cd9d4b74b5c1fa80363ec590.
#
# 2024/10/07 15:36:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  73%|███████▎  | 11/15 [00:49<00:17,  4.39s/trial, best loss: 5.335419588556921]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run silent-worm-135 at: http://127.0.0.1:5000/#/experiments/2/runs/1aac21af5f544c46b0f265b20ea8a7b6.
#
# 2024/10/07 15:36:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  80%|████████  | 12/15 [00:52<00:11,  3.94s/trial, best loss: 5.335419588556921]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run salty-cub-724 at: http://127.0.0.1:5000/#/experiments/2/runs/1c2d0d937f1b4ee39bd275910aa29029.
#
# 2024/10/07 15:36:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  87%|████████▋ | 13/15 [00:53<00:06,  3.07s/trial, best loss: 5.335419588556921]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run delightful-horse-269 at: http://127.0.0.1:5000/#/experiments/2/runs/c39112553a604e0097fa011f28c929c1.
#
# 2024/10/07 15:36:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
#  93%|█████████▎| 14/15 [00:57<00:03,  3.14s/trial, best loss: 5.335419588556921]/home/codespace/anaconda3/envs/vishal-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/10/07 15:36:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run crawling-bass-235 at: http://127.0.0.1:5000/#/experiments/2/runs/fe155ce01a6345c79e860600fbbf550c.
#
# 2024/10/07 15:36:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2.
#
# 100%|██████████| 15/15 [01:02<00:00,  4.15s/trial, best loss: 5.335419588556921]

# %%
What's the best validation RMSE that you got? = 5.335   [run outpu15/15 [01:02<00:00,  4.15s/trial, best loss: 5.335419588556921]
corr
